# %%
1+1+1
# Out:
# 运行具有“gemini_in_chrome (Python 3.12.12)”的单元格需要ipykernel包。
#
# 使用所需的包 <a href='command:jupyter.createPythonEnvAndSelectController'>创建 Python 环境</a>。
#
# 或使用命令“conda install -n gemini_in_chrome ipykernel --update-deps --force-reinstall”安装“ipykernel”
